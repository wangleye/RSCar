# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.figure()

# %%
plt.figure()
plt.plot([3,4,2,1])

# %% [markdown]
# This is just a **simple** example for using jupyter notebook

# %%
plt.plot([2,4,3,1])

# %%
for i in range(5):
    print(i)
    plt.figure()
    plt.plot([i,i,i,i])
print ("gogogog")
# Out:
# 0
# 1
# 2
# 3
# 4
# gogogog
